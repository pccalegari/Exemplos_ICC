# %% [markdown]
# <a href="https://colab.research.google.com/github/pccalegari/Exemplos_ICC/blob/main/Planilhas_p1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

temperatura = pd.read_csv("sample_data/temperatura.csv")

temperatura.head()
# Out:
#       Dias  POAmax  POAmin  FLPmax  FLPmin  CTBmax  CTBmin  Spmax  Spmin  \
# 0    Sexta      26      17      24      18      24      14     25     16
# 1   Sábado      26      16      23      17      24      14     26     15
# 2  Domingo      27      16      22      16      24      14     26     16
# 3  Segunda      24      16      26      17      26      14     25     14
# 4    Terça      25      14      24      16      24      13     25     15
#
#    GYNmax  GYNmin  BELmax  BELmin  NTLmax  NTLmin
# 0      30      16      31      24      30      24
# 1      29      15      34      24      29      23
# 2      29      15      33      24      30      22
# 3      29      14      32      24      29      23
# 4      29      14      34      23      30      23

# %%
TmaxPOA = temperatura["POAmax"]
TmaxPOA.head()

TPOA = temperatura[["POAmax", "POAmin"]]
TPOA.head()

TFLP = temperatura[["FLPmax", "FLPmin"]]
TFLP.head()
# Out:
#    FLPmax  FLPmin
# 0      24      18
# 1      23      17
# 2      22      16
# 3      26      17
# 4      24      16

# %%
temperatura[["POAmax", "POAmin"]].mean()
temperatura[["POAmax", "POAmin"]].describe()
# Out:
#           POAmax     POAmin
# count   6.000000   6.000000
# mean   25.833333  15.833333
# std     1.169045   0.983192
# min    24.000000  14.000000
# 25%    25.250000  16.000000
# 50%    26.000000  16.000000
# 75%    26.750000  16.000000
# max    27.000000  17.000000
